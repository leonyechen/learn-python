# %%
st = 'Print only the words that start with s in this sentence'

# %%
for word in st.split():
    if word[0] == 's':
        print(f'{word} start with a s')
# Out:
# start start with a s
# s start with a s
# sentence start with a s

# %%
st = 'Print every word in this sentence that has an even number of letters'

# %%
for word in st.split():
    word_len = len(word)
    if word_len % 2 == 0:
        print(f"{word}'s len is {word_len}'")
# Out:
# word's len is 4'
# in's len is 2'
# this's len is 4'
# sentence's len is 8'
# that's len is 4'
# an's len is 2'
# even's len is 4'
# number's len is 6'
# of's len is 2'

# %%
for num in range(1, 1001):
    if num % 3 == 0 and num % 5 == 0:
        print(f"FizzBuzz{num}")
        
    elif num % 3 == 0:
        print(f"Fizz{num}")
        
    elif num % 5 == 0:
        print(f"Buzz{num}")
        
    elif num % 1 == 0:
        print(num)
# Out:
# 1
# 2
# Fizz3
# 4
# Buzz5
# Fizz6
# 7
# 8
# Fizz9
# Buzz10
# 11
# Fizz12
# 13
# 14
# FizzBuzz15
# 16
# 17
# Fizz18
# 19
# Buzz20
# Fizz21
# 22
# 23
# Fizz24
# Buzz25
# 26
# Fizz27
# 28
# 29
# FizzBuzz30
# 31
# 32
# Fizz33
# 34
# Buzz35
# Fizz36
# 37
# 38
# Fizz39
# Buzz40
# 41
# Fizz42
# 43
# 44
# FizzBuzz45
# 46
# 47
# Fizz48
# 49
# Buzz50
# Fizz51
# 52
# 53
# Fizz54
# Buzz55
# 56
# Fizz57
# 58
# 59
# FizzBuzz60
# 61
# 62
# Fizz63
# 64
# Buzz65
# Fizz66
# 67
# 68
# Fizz69
# Buzz70
# 71
# Fizz72
# 73
# 74
# FizzBuzz75
# 76
# 77
# Fizz78
# 79
# Buzz80
# Fizz81
# 82
# 83
# Fizz84
# Buzz85
# 86
# Fizz87
# 88
# 89
# FizzBuzz90
# 91
# 92
# Fizz93
# 94
# Buzz95
# Fizz96
# 97
# 98
# Fizz99
# Buzz100
# 101
# Fizz102
# 103
# 104
# FizzBuzz105
# 106
# 107
# Fizz108
# 109
# Buzz110
# Fizz111
# 112
# 113
# Fizz114
# Buzz115
# 116
# Fizz117
# 118
# 119
# FizzBuzz120
# 121
# 122
# Fizz123
# 124
# Buzz125
# Fizz126
# 127
# 128
# Fizz129
# Buzz130
# 131
# Fizz132
# 133
# 134
# FizzBuzz135
# 136
# ...

# %%
myList = [38, 25, 68, 128, 87, 268, 3569, 28]

# %%
min(myList)
# Out:
# 25

# %%
max(myList)
# Out:
# 3569

# %%
minNum = myList[0]

# %%
print(minNum)
# Out:
# 38

# %%
for num in myList[1::]:
    print(num)
    if num < minNum:
        minNum = num
# Out:
# 25
# 68
# 128
# 87
# 268
# 3569
# 28

# %%
print(minNum)
# Out:
# 25

# %%
maxnum = myList[0]

# %%
for num in myList[1::]:
    if num > maxnum:
        maxnum = num

# %%
print(maxnum)
# Out:
# 3569

# %%
myList = [38, 25, 68, 128, 87, 268, 3569, 28]

# %%
myList.sort()

# %%
myList
# Out:
# [25, 28, 38, 68, 87, 128, 268, 3569]

# %%
myList[1]
# Out:
# 28

# %%
myList[len(myList)-2]
# Out:
# 268

# %%
myList = [38, 25, 68, 128, 87, 268, 3569, 28]

# %%
minNum = myList[0]

# %%
for num in myList[1::]:
    print(num)
    if num < minNum:
        minNum = num
# Out:
# 25
# 68
# 128
# 87
# 268
# 3569
# 28

# %%
minNum
# Out:
# 25

# %%
secondMin = None
for num in myList:
    if num > minNum:
        if secondMin is None or num < secondMin:
            secondMin = num

# %%
secondMin
# Out:
# 28

# %%
my_list1 = [10,5,20,76,95,38]

# %%
my_list1
# Out:
# [10, 5, 20, 76, 95, 38]

# %%
minnum = None

# %%
minnum
# Out:
# 10

# %%
secondmin = None

# %%
secondmin
# Out:
# 10

# %%
for num in my_list1:
    if minnum == None:
        minnum = num
        
        
        
    elif secondmin is None:
        secondmin = num
